# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
categorical = pd.read_csv('categorical.csv')

# %%
categorical
# Out:
#       OSOURCE  STATE    ZIP MAILCODE NOEXCH MDMAUD  CLUSTER HOMEOWNR GENDER  \
# 0         GRI     IL  61081        A      0   XXXX     36.0      NaN      F
# 1         BOA     CA  91326        A      0   XXXX     14.0        H      M
# 2         AMH     NC  27017        A      0   XXXX     43.0        U      M
# 3         BRY     CA  95953        A      0   XXXX     44.0        U      F
# 4         NaN     FL  33176        A      0   XXXX     16.0        H      F
# ...       ...    ...    ...      ...    ...    ...      ...      ...    ...
# 95407     ASE  other  99504        A      0   XXXX     27.0      NaN      M
# 95408     DCD     TX  77379        A      0   XXXX     24.0        H      M
# 95409     MBC     MI  48910        A      0   XXXX     30.0      NaN      M
# 95410     PRV     CA  91320        A      0   XXXX     24.0        H      F
# 95411     MCC     NC  28409        A      0   C1CM     24.0        U      F
#
# ...

# %%
drop_columns_list = []

# %%
nulls_percent_df = pd.DataFrame(categorical.isna().sum()*100/len(categorical)).reset_index()
nulls_percent_df.columns = ['column_name', 'nulls_percentage']
nulls_percent_df.head()
# Out:
#   column_name  nulls_percentage
# 0     OSOURCE          0.972624
# 1       STATE          0.000000
# 2         ZIP          0.000000
# 3    MAILCODE          0.000000
# 4      NOEXCH          0.007337

# %%
columns_above_threshold = nulls_percent_df[nulls_percent_df['nulls_percentage']>50]
print(len(columns_above_threshold['column_name']))
# Out:
# 2

# %%
drop_columns_list = list(columns_above_threshold['column_name'])
print(drop_columns_list)
# Out:
# ['SOLIH', 'VETERANS']

# %%
print(categorical['GENDER'].value_counts())
categorical['GENDER'] = categorical['GENDER'].fillna('F')
# Out:
# F    51277
# M    39094
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
categorical['GENDER'] = categorical['GENDER'].apply(lambda x: x.replace("C", "F"))

# %%
categorical['GENDER'] = categorical['GENDER'].apply(lambda x: x.replace("A", "M"))

# %%
categorical['GENDER'] = categorical['GENDER'].apply(lambda x: x.replace("J", "U"))

# %%
print(categorical['GENDER'].value_counts())
# Out:
# F    54236
# M    39096
# U     2080
# Name: GENDER, dtype: int64

# %%
cols = ['OSOURCE', 'ZIP']
for item in cols:
    drop_columns_list.append(item)  
print(drop_columns_list)
# Out:
# ['SOLIH', 'VETERANS', 'OSOURCE', 'ZIP']
